# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/tpathuri/Downloads/CLAIMS.csv")

# %%
df.head()
# Out:
#   FRAUDFOUND  WEEKOFMONTH DAYOFWEEK       MAKE ACCIDENTAREA DAYOFWEEKCLAIMED  \
# 0        Yes            5    Friday    Pontiac        Rural           Monday
# 1         No            2    Sunday     Toyota        Urban           Friday
# 2        Yes            5    Friday     Toyota        Urban           Friday
# 3        Yes            5    Friday     Toyota        Urban          Tuesday
# 4        Yes            5  Saturday  Chevrolet        Urban         Thursday
#
#   MONTHCLAIMED  WEEKOFMONTHCLAIMED     SEX MARITALSTATUS  ...  \
# 0          Jan                   5    Male        Single  ...
# 1          May                   2  Female       Married  ...
# 2          Feb                   2    Male       Married  ...
# 3          Feb                   1    Male       Married  ...
# 4          Feb                   2    Male       Married  ...
#
#   PASTNUMBEROFCLAIMS AGEOFVEHICLE AGEOFPOLICYHOLDER  POLICEREPORTFILED  \
# 0               none       6years            31to35                 No
# 1                  1       6years            36to40                 No
# 2               2to4    morethan7            51to65                 No
# 3               2to4    morethan7            51to65                 No
# 4                  1       5years            31to35                 No
#
#    WITNESSPRESENT  AGENTTYPE  NUMBEROFSUPPLIMENTS ADDRESSCHANGE-CLAIM  \
# 0              No   External                 none            nochange
# 1              No   External                 none            nochange
# 2              No   External                 none            nochange
# 3              No   External            morethan5               1year
# 4              No   External                 none            nochange
#
#   NUMBEROFCARS BASEPOLICY
# 0     1vehicle  AllPerils
# 1         3to4  Collision
# 2     1vehicle  AllPerils
# 3     1vehicle  AllPerils
# 4     1vehicle  AllPerils
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1782 entries, 0 to 1781
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   FRAUDFOUND            1782 non-null   object
#  1   WEEKOFMONTH           1782 non-null   int64
#  2   DAYOFWEEK             1782 non-null   object
#  3   MAKE                  1782 non-null   object
#  4   ACCIDENTAREA          1782 non-null   object
#  5   DAYOFWEEKCLAIMED      1782 non-null   object
#  6   MONTHCLAIMED          1782 non-null   object
#  7   WEEKOFMONTHCLAIMED    1782 non-null   int64
#  8   SEX                   1782 non-null   object
#  9   MARITALSTATUS         1782 non-null   object
#  10  FAULT                 1782 non-null   object
#  11  VEHICLECATEGORY       1782 non-null   object
#  12  VEHICLEPRICE          1782 non-null   object
#  13  POLICYNUMBER          1782 non-null   int64
#  14  REPNUMBER             1782 non-null   int64
#  15  DEDUCTIBLE            1782 non-null   int64
#  16  DRIVERRATING          1782 non-null   int64
#  17  DAYS:POLICY-ACCIDENT  1782 non-null   object
#  18  DAYS:POLICY-CLAIM     1782 non-null   object
#  19  PASTNUMBEROFCLAIMS    1782 non-null   object
#  20  AGEOFVEHICLE          1782 non-null   object
#  21  AGEOFPOLICYHOLDER     1782 non-null   object
#  22  POLICEREPORTFILED     1782 non-null   object
#  23  WITNESSPRESENT        1782 non-null   object
#  24  AGENTTYPE             1782 non-null   object
#  25  NUMBEROFSUPPLIMENTS   1782 non-null   object
#  26  ADDRESSCHANGE-CLAIM   1782 non-null   object
#  27  NUMBEROFCARS          1782 non-null   object
#  28  BASEPOLICY            1782 non-null   object
# dtypes: int64(6), object(23)
# memory usage: 403.9+ KB

# %%
df.describe()
# Out:
#        WEEKOFMONTH  WEEKOFMONTHCLAIMED  POLICYNUMBER    REPNUMBER  \
# count  1782.000000         1782.000000   1782.000000  1782.000000
# mean      2.749158            2.681257   7524.725028     8.379349
# std       1.275800            1.273616   4430.396357     4.579791
# min       1.000000            1.000000      1.000000     1.000000
# 25%       2.000000            2.000000   3634.250000     5.000000
# 50%       3.000000            3.000000   7408.000000     8.000000
# 75%       4.000000            4.000000  11359.500000    12.000000
# max       5.000000            5.000000  15420.000000    16.000000
#
#         DEDUCTIBLE  DRIVERRATING
# count  1782.000000   1782.000000
# mean    409.483726      2.515713
# std      46.250332      1.126243
# min     300.000000      1.000000
# 25%     400.000000      1.000000
# 50%     400.000000      3.000000
# 75%     400.000000      4.000000
# max     700.000000      4.000000

# %%
df.shape
# Out:
# (1782, 29)

# %%
df['MAKE'].unique()
# Out:
# array(['Pontiac', 'Toyota', 'Chevrolet', 'Mazda', 'Honda', 'Ford',
#        'Accura', 'VW', 'Saturn', 'Saab', 'Dodge', 'Nisson', 'Mecedes',
#        'Mercury', 'BMW'], dtype=object)

# %%
df.isnull().sum()
# Out:
# FRAUDFOUND              0
# WEEKOFMONTH             0
# DAYOFWEEK               0
# MAKE                    0
# ACCIDENTAREA            0
# DAYOFWEEKCLAIMED        0
# MONTHCLAIMED            0
# WEEKOFMONTHCLAIMED      0
# SEX                     0
# MARITALSTATUS           0
# FAULT                   0
# VEHICLECATEGORY         0
# VEHICLEPRICE            0
# POLICYNUMBER            0
# REPNUMBER               0
# DEDUCTIBLE              0
# DRIVERRATING            0
# DAYS:POLICY-ACCIDENT    0
# DAYS:POLICY-CLAIM       0
# PASTNUMBEROFCLAIMS      0
# AGEOFVEHICLE            0
# AGEOFPOLICYHOLDER       0
# POLICEREPORTFILED       0
# WITNESSPRESENT          0
# AGENTTYPE               0
# NUMBEROFSUPPLIMENTS     0
# ADDRESSCHANGE-CLAIM     0
# NUMBEROFCARS            0
# BASEPOLICY              0
# dtype: int64

# %%
pd.set_option('display.max_columns', None)  # Set the option to display all columns
df.head()
# Out:
#   FRAUDFOUND  WEEKOFMONTH DAYOFWEEK       MAKE ACCIDENTAREA DAYOFWEEKCLAIMED  \
# 0        Yes            5    Friday    Pontiac        Rural           Monday
# 1         No            2    Sunday     Toyota        Urban           Friday
# 2        Yes            5    Friday     Toyota        Urban           Friday
# 3        Yes            5    Friday     Toyota        Urban          Tuesday
# 4        Yes            5  Saturday  Chevrolet        Urban         Thursday
#
#   MONTHCLAIMED  WEEKOFMONTHCLAIMED     SEX MARITALSTATUS         FAULT  \
# 0          Jan                   5    Male        Single  PolicyHolder
# 1          May                   2  Female       Married    ThirdParty
# 2          Feb                   2    Male       Married  PolicyHolder
# 3          Feb                   1    Male       Married  PolicyHolder
# 4          Feb                   2    Male       Married  PolicyHolder
#
#   VEHICLECATEGORY      VEHICLEPRICE  POLICYNUMBER  REPNUMBER  DEDUCTIBLE  \
# 0           Sedan  40_000 to 59_000           901          7         400
# 1           Sedan  20_000 to 29_000           903         11         400
# 2           Sedan  20_000 to 29_000           906         13         400
# 3           Sedan  20_000 to 29_000           911         16         400
# 4           Sedan  20_000 to 29_000           937         14         400
#
#    DRIVERRATING DAYS:POLICY-ACCIDENT DAYS:POLICY-CLAIM PASTNUMBEROFCLAIMS  \
# 0             1           morethan30        morethan30               none
# 1             3           morethan30        morethan30                  1
# 2             1           morethan30        morethan30               2to4
# 3             2           morethan30        morethan30               2to4
# 4             4           morethan30        morethan30                  1
#
#   AGEOFVEHICLE AGEOFPOLICYHOLDER POLICEREPORTFILED WITNESSPRESENT AGENTTYPE  \
# 0       6years            31to35                No             No  External
# 1       6years            36to40                No             No  External
# 2    morethan7            51to65                No             No  External
# 3    morethan7            51to65                No             No  External
# 4       5years            31to35                No             No  External
#
#   NUMBEROFSUPPLIMENTS ADDRESSCHANGE-CLAIM NUMBEROFCARS BASEPOLICY
# 0                none            nochange     1vehicle  AllPerils
# 1                none            nochange         3to4  Collision
# 2                none            nochange     1vehicle  AllPerils
# 3           morethan5               1year     1vehicle  AllPerils
# 4                none            nochange     1vehicle  AllPerils
